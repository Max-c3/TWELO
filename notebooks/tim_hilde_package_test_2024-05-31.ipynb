# %%
from twelo.data import prepare_dataset, load_dataset
from twelo.registry import load_model
from twelo.model import compile_model, create_new_model, train_model, preprocess_data
from twelo.params import *

# %%
history, model = train_model()
# Out:
# Creating new yolo model.
# <class 'keras_cv.src.models.object_detection.yolo_v8.yolo_v8_detector.YOLOV8Detector'>
# Compiling model.
# Preparing dataset.
# Loading dataset.
# Loading dataset.
# Training model.
# Epoch 1/2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 history, model = train_model()
#
# File ~/code/tim-hilde/Kestrix/kestrix/model.py:59, in train_model(new, model_path)
#      54 coco_metrics_callback = keras_cv.callbacks.PyCOCOCallback(
#      55     val_ds,
#      56     BOUNDING_BOX_FORMAT)
#      58 print("Training model.")
# ---> 59 history = model.fit(
#      60     train_ds,
#      61     validation_data=val_ds,
#      62     epochs=2,
#      63     callbacks=[coco_metrics_callback],
#      64 )
#      65 save_model(model)
#      67 return history, model
#
# ...
